# %%
import numpy as np

def custom_svd(X, k):

    # Truncated SVD
    U, S, VT = np.linalg.svd(X, full_matrices=False)

    # Giảm chiều dữ liệu
    X_result = U[:, :k] @ np.diag(S[:k])

    return X_result

# %%
import numpy as np

def custom_svd(X, k):

    # Truncated SVD
    U, S, VT = np.linalg.svd(X, full_matrices=False)

    # Giảm chiều dữ liệu
    X_result = U[:, :k] @ np.diag(S[:k])

    return X_result

A = np.array([
    [67, 69],
    [69, 67],
    [67, 67]
])

print("1. Ma trận ban đầu A:")
print(A)

# Giảm chiều với k = 1
A_reduced = custom_svd(A, k=1)

print("\n2. Ma trận A sau khi giảm chiều bằng SVD (k = 1):")
print(A_reduced)
# Out:
# 1. Ma trận ban đầu A:
# [[67 69]
#  [69 67]
#  [67 67]]
#
# 2. Ma trận A sau khi giảm chiều bằng SVD (k = 1):
# [[-96.16652224]
#  [-96.16652224]
#  [-94.75230868]]

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
import numpy as np

def custom_svd(X, k):

    # Truncated SVD
    U, S, VT = np.linalg.svd(X, full_matrices=False)

    # Giảm chiều dữ liệu
    X_result = U[:, :k] @ np.diag(S[:k])

    return X_result

iris = load_iris()
X = iris.data
y = iris.target

#Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# Truncated SVD
X_svd = custom_svd(X_std, k=2)

# Vẽ bảng
plt.figure(figsize=(8,6))

for i, name in enumerate(iris.target_names):
    plt.scatter(
        X_svd[y == i, 0],
        X_svd[y == i, 1],
        label=name
    )

plt.xlabel("SVD Component 1")
plt.ylabel("SVD Component 2")
plt.title("Trực quan hóa bộ dữ liệu Iris bằng SVD")
plt.legend()
plt.show()
